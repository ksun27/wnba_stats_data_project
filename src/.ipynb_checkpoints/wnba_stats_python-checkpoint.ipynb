# %% [markdown]
# # Kevin Sun WNBA Stats Project

# %% [markdown]
# ## Part 1 - Questions
#
# ### Question 1:
#
# What is the average Player Efficiency Rating among WNBA players from 1997-2019?
#
# * Who (population): WNBA Players
# * What (subject, discipline): Baskeball, WNBA Statistics
# * Where (location): WNBA League in North America
# * When (snapshot, longitudinal): 1997-2019 WNBA Seasons, N/A
# * How much data do you need to do the analysis/work: CSV with WNBA Player Statistics highlighting Player Efficiency Rating
#
# ### Question 2:
#
# What is the average age of players among WNBA players from 1997-2019?
#
# * Who (population): WNBA Players
# * What (subject, discipline): Baskeball, WNBA Statistics
# * Where (location): WNBA League in North America
# * When (snapshot, longitudinal): 1997-2019 WNBA Seasons, N/A
# * How much data do you need to do the analysis/work: CSV with WNBA Player Statistics highlighting age and season
#
# ### Question 3:
#
# Who is the has the highest Player Efficiency Rating among WNBA players from 1997-2019?
#
# * Who (population): WNBA Players
# * What (subject, discipline): Baskeball, WNBA Statistics
# * Where (location): WNBA League in North America
# * When (snapshot, longitudinal): 1997-2019 WNBA Seasons, N/A
# * How much data do you need to do the analysis/work: CSV with WNBA Player Statistics highlighting Player Name and Player Efficiency Rating
#
# ### Who Might Collect Relevant Data / What Articles or Publications Cite a Relevant Data Set?
#
# The WNBA may already collect statistics and data regarding WNBA players, so I can possibly look on the WNBA website for more details. There are also other websites that are collecting data regarding WNBA players and those may also be useful when trying to find the relevant data to answer these questions.

# %% [markdown]
# ## Part 2 - Selecting a Data Set, Adding Documentation
#
#
#
# 1. Name / Title: wnba-player-stats
# 2. Link to Data: https://github.com/fivethirtyeight/WNBA-stats
# 3. Source / Origin:
# 	* Author or Creator: Neil Paine
# 	* Publication Date: May 25, 2020
# 	* Publisher: FiveThirtyEight
# 	* Version or Data Accessed: 2/3/2021
# 4. License: Creative Commons Attribution 4.0 International license

# %% [markdown]
# ## Format

# %% [markdown]
# ### Overview
#
# * Format: .csv (comma separated values)
# * Size: 530 KB (543,266 bytes)
# * Number of Records: 3884

# %% [markdown]
# ### Sample of Data

# %%
import csv

with open('../data/raw/wnba-player-stats.csv', 'r') as f:
    reader = csv.reader(f, delimiter=",", quotechar='"')
    next(reader, None)
    data_read = [row for row in reader]
    for i in range(0,3):
        print(data_read[i])
# Out:
# ['montgre01w', 'Renee Montgomery', '2019', '32', 'ATL', '34', '-9.8', 'G', '34', '949', '69.5%', '11.1', '.520', '.727', '.176', '1.0', '4.1', '18.0', '1.7', '0.5', '16.8', '17.5', '0.4', '0.5', '0.9', '.039', '-2.4', '1.22']
# ['williel01w', 'Elizabeth Williams', '2019', '26', 'ATL', '34', '-9.8', 'C-F', '32', '909', '66.6%', '16.7', '.521', '.000', '.477', '11.4', '12.1', '7.8', '1.4', '4.7', '12.9', '15.9', '1.6', '1.0', '2.7', '.117', '+0.6', '2.51']
# ['sykesbr01w', 'Brittney Sykes', '2019', '25', 'ATL', '34', '-9.8', 'G', '34', '880', '64.5%', '11.3', '.445', '.308', '.259', '3.0', '9.1', '19.6', '1.2', '1.5', '14.8', '23.1', '-0.8', '0.8', '0.0', '-.001', '-3.4', '0.70']

# %% [markdown]
# ### Fields or Column Headers
#
# * Field/Column 1: Player Name (String)
# * Field/Column 2: Year (String)
# * Field/Column 3: Age (Integer)
# * Field/Column 4: Player Efficiency Rating (Float)

# %% [markdown]
# ## Part 3 - Extract / Transform
#
# Process for extracting, transforming, cleaning incoming data:
#
# Columns that I plan on using are the Player Name, Year, Age, and Player Efficiency Rating columns from my dataset.
#
# The Player Name column is already a string which I need. The Year column is tricky, as it is a numerical type but I still need it in the type of string as it is a categorical data type rather than a quantitative one. For Age and Player Efficiency Rating I will need to convert to Integer and Float types.
#
# There are some empty numerical cells for players and those will be turned into 0 because in this case means that there are not statistics recorded for that player. It will show up as an empty string so it is necessary to fill in those cells. I also need to change some of the data types for some columns.
#
# I'll use a generator to take in values from columns that I want. I will then put this data into a list where I can manipulate and hopefully answer the questions that I came up with.

# %%
import csv
        
def get_player_name():
    with open('../data/raw/wnba-player-stats.csv', 'r') as f:
        reader = csv.reader(f, delimiter=",", quotechar='"')
        next(reader, None)
        data_read = [row for row in reader]
        for i in range(len(data_read)):
            #if data_read[i][1] == None:
            yield data_read[i][1]

def get_year():
    with open('../data/raw/wnba-player-stats.csv', 'r') as f:
        reader = csv.reader(f, delimiter=",", quotechar='"')
        next(reader, None)
        data_read = [row for row in reader]
        for i in range(len(data_read)):
            yield data_read[i][2]
        
def get_age():
    with open('../data/raw/wnba-player-stats.csv', 'r') as f:
        reader = csv.reader(f, delimiter=",", quotechar='"')
        next(reader, None)
        data_read = [row for row in reader]
        for i in range(len(data_read)):
            if data_read[i][3] == '':
                data_read[i][3] = 0
            yield int(data_read[i][3])

def get_PER():
    with open('../data/raw/wnba-player-stats.csv', 'r') as f:
        reader = csv.reader(f, delimiter=",", quotechar='"')
        next(reader, None)
        data_read = [row for row in reader]
        print(data_read[12][11])
        for i in range(len(data_read)):
            if data_read[i][11] == '':
                data_read[i][11] = 0
            yield float(data_read[i][11])
        
player_names = list(get_player_name())
years = list(get_year())
ages = list(get_age())
PERS = list(get_PER())

# %% [markdown]
# ## Part 4 - Descriptive Statistics
#
# ### Analysis on Numeric Data
#
# ### Range, Outliers

# %%
def r(data):
    return max(data) - min(data)

# %%
r(PERS)
# Out:
# 190.8

# %%
max(PERS)
# Out:
# 78.9

# %%
min(PERS)
# Out:
# -111.9

# %% [markdown]
# #### Central Tendency

# %%
def mean(data):
    return sum(data)/len(data)

# %%
mean(PERS)
# Out:
# 11.900386299253112

# %%
def median(data):
    d = sorted(data)
    i = len(d) // 2
    # if even, mean of two middle values
    return d[i] if len(d) % 2 == 1 else mean(d[i-1: i+1])

# %%
median(PERS)
# Out:
# 12.3

# %%
def mode(data):
    counts = {}
    for val in data:
        if val in counts:
            counts[val] += 1
        else:
            counts[val] = 1
    return sorted(counts.items(), key=lambda t: t[1])[-1][0] if len(counts) > 0 else None

# %%
mode(PERS)
# Out:
# 11.1

# %% [markdown]
# #### Dispersion

# %%
def variance(data):
    mu = mean(data)
    return sum((x - mu) ** 2 for x in data) / len(data)

# %%
variance(PERS)
# Out:
# 64.2210325574431

# %%
def standard_deviation(data):
    return variance(data) ** 0.5

# %%
standard_deviation(PERS)
# Out:
# 8.013802627806795

# %%
r(PERS)
# Out:
# 190.8

# %% [markdown]
# #### Other - IQR

# %%
quantile = lambda p, data: sorted(data)[int(p * len(data))]

# %%
def iqr(data):
    return quantile(0.75, data) - quantile(0.25, data)

# %%
iqr(PERS)
# Out:
# 7.999999999999998

# %% [markdown]
# ###  Analysis on Categorical Data

# %% [markdown]
# #### Frequency

# %%
from collections import Counter
c = Counter(years)
c
# Out:
# Counter({'2019': 163,
#          '2018': 165,
#          '2017': 168,
#          '2016': 166,
#          '2015': 168,
#          '2014': 156,
#          '2013': 151,
#          '2012': 152,
#          '2011': 149,
#          '2010': 152,
#          '2009': 171,
#          '2008': 205,
#          '2007': 180,
#          '2006': 186,
#          '2005': 181,
#          '2004': 168,
#          '2003': 182,
#          '2002': 219,
#          '2001': 209,
#          '2000': 208,
#          '1999': 156,
#          '1998': 130,
#          '1997': 98})

# %% [markdown]
# #### Unique Values

# %%
set(player_names)
# Out:
# {"A'Quonesia Franklin",
#  "A'dia Mathies",
#  "A'ja Wilson",
#  'Aaryn Ellenberg',
#  'Abby Bishop',
#  'Abi Olajuwon',
#  'Adaora Elonu',
#  'Adia Barnes',
#  'Adrian Williams-Strong',
#  'Adriana Moises',
#  'Adrianne Ross',
#  'Adrienne Goodson',
#  'Adrienne Johnson',
#  'Adrienne Shuler',
#  'Adut Bulgak',
#  'Aerial Powers',
#  'Agnieszka Bibrzycka',
#  'Aiysha Smith',
#  'Alaina Coates',
#  'Alana Beard',
#  'Alanna Smith',
#  'Albena Branzova',
#  'Alessandra Santos de Oliveira',
#  'Alex Bentley',
#  'Alex Harden',
#  'Alex Montgomery',
#  'Alexis Gray-Lawson',
#  'Alexis Hornbuckle',
#  'Alexis Jones',
#  'Alexis Peterson',
#  'Alexis Prince',
#  'Alicia Thompson',
#  'Alisa Burras',
#  'Alison Bales',
#  'Alison Lacey',
#  'Allie Quigley',
#  'Allisha Gray',
#  'Allison Feaster',
#  'Allison Hightower',
#  'Ally Malott',
#  'Alysha Clark',
#  'Alyssa Thomas',
#  'Amanda Lassiter',
#  'Amanda Thompson',
#  'Amanda Wilson',
#  'Amanda Zahui B.',
#  'Amaya Valdemoro',
#  'Amber Hall',
#  'Amber Harris',
#  'Amber Holt',
#  'Amber Jacobs',
#  'Ambrosia Anderson',
#  'Ameryst Alston',
#  'Amisha Carter',
#  'Amy Herrig',
#  'Amy Sanders',
#  'Ana Dabovic',
#  'Anastasia Kostaki',
#  'Andrea Congreaves',
#  'Andrea Gardner',
#  'Andrea Garner',
#  'Andrea Hoover',
#  'Andrea Kuklova',
#  'Andrea Lloyd Curry',
#  'Andrea Nagy',
#  'Andrea Riley',
#  'Andrea Stinson',
#  'Aneika Henry-Morello',
#  'Aneta Kausaite',
#  'Anete Jekabsone-Zogota',
#  'Angel Goodrich',
#  'Angel McCoughtry',
#  'Angel Robinson',
#  'Angela Aycock',
#  'Angela Jackson',
#  'Angelina Williams',
#  'Angelina Wolvert',
#  'Angie Bjorklund',
#  'Angie Braziel',
#  'Angie Hamblin',
#  'Angie Potthoff',
#  'Anita Maxwell',
#  'Ann Strother',
#  'Ann Wauters',
#  'Anna Cruz',
#  'Anna DeForge',
#  'Anna Montanana',
#  'Anne Marie Armstrong',
#  'Annie Burgess',
#  'Anriel Howard',
#  'April Sykes',
#  'Arica Carter',
#  'Ariel Atkins',
#  'Arike Ogunbowale',
#  'Armintie Herrington',
#  'Ashley Battle',
#  'Ashley Houts',
#  'Ashley Robinson',
#  'Ashley Shields',
#  'Ashley Walker',
#  'Asia Durr',
#  'Asia Taylor',
#  'Asjha Jones',
#  'Astou Ndiaye-Diatta',
#  'Astou Ndour',
#  'Audrey Sauret',
#  'Avery Warley-Talbert',
#  'Ayana Walker',
#  'Azura Stevens',
#  'Barbara Farris',
#  'Barbara Turner',
#  'Bashaara Graves',
#  'Becky Hammon',
#  'Begona Garcia',
#  'Belinda Snell',
#  'Bernadette Ngoyisa',
#  'Bernice Mosby',
#  'Beth Cunningham',
#  'Bethany Donaphin',
#  'Betnijah Laney',
#  'Betty Lennox',
#  'Beverly Williams',
#  'Blake Dietrick',
#  'Brandi Davis',
#  'Brandi McCain',
#  'Brandy Reed',
#  'Breanna Lewis',
#  'Breanna Stewart',
#  'Brene Moseley',
#  'Bria Hartley',
#  'Bria Holmes',
#  'Briana Gilbreath-Butler',
#  'Briann January',
#  'Brianna Kiesel',
#  'Brianna Turner',
#  'Bridget Carleton',
#  'Bridget Pettis',
#  'Bridgette Gordon',
#  'Brionna Jones',
#  'Britany Miller',
#  'Brittainey Raven',
#  'Brittany Boyd',
#  'Brittany Hrynko',
#  'Brittany Wilkins',
#  'Brittney Griner',
#  'Brittney Sykes',
#  'Brooke McCarty-Williams',
#  'Brooke Queenan',
#  'Brooke Smith',
#  'Brooke Wyckoff',
#  'Caity Matter',
#  'Camille Cooper',
#  'Camille Little',
#  'Candace Futrell',
#  'Candace Parker',
#  'Candice Dupree',
#  'Candice Wiggins',
#  'Cappie Pondexter',
#  'Cara Consuegra',
#  'Carla Boyd',
#  'Carla Cortijo',
#  'Carla McGhee',
#  'Carla Thomas',
#  'Carolyn Moos',
#  'Carolyn Swords',
#  'Carolyn Young',
#  'Cass Bauer-Bilodeau',
#  'Cassandra Crumpton-Moorer',
#  'Catarina Pollini',
#  'Cathrine Kraayeveld',
#  'Cathy Joens',
#  'Cayla George',
#  'Cecilia Zandalasini',
#  'Celine Dumerc',
#  'Chamique Holdsclaw',
#  'Chandi Jones',
#  'Chandra Johnson',
#  'Chanel Mokango',
#  'Chante Black',
#  'Chantel Tremitiere',
#  'Chantelle Anderson',
#  'Charde Houston',
#  'Charel Allen',
#  'Charisse Sampson',
#  'Charlotte Smith',
#  'Charmin Smith',
#  'Chasity Melvin',
#  'Chastity Reed',
#  'Chay Shegog',
#  'Chelsea Gray',
#  'Chelsea Hopkins',
#  'Chelsea Newton',
#  'Chelsea Poppens',
#  'Chen Nan',
#  'Cheryl Ford',
#  'Cheyenne Parker',
#  'Chiney Ogwumike',
#  'Chioma Nnamaka',
#  'Chloe Jackson',
#  'Chrissy Givens',
#  "Christelle N'Garsanet",
#  'Christi Thomas',
#  'Christina Wirth',
#  'Christy Smith',
#  'Chucky Jeffery',
#  'Cierra Bravard',
#  'Cierra Burdick',
#  'Cindy Blodgett',
#  'Cindy Brown',
#  'Cintia dos Santos',
#  'Cisti Greenwalt',
#  'Claire Coggins',
#  'Clarissa Davis-Wrightsil',
#  'Clarissa Dos Santos',
#  'Clarisse Machanguana',
#  'Claudia Neves',
#  'Coco Miller',
#  'Coquese Washington',
#  'Coretta Brown',
#  'Cori Chambers',
#  'Corissa Yasen',
#  'Cornelia Gayden',
#  'Courtney Clements',
#  'Courtney Coleman',
#  'Courtney Paris',
#  'Courtney Vandersloot',
#  'Courtney Williams',
#  'Crystal Bradford',
#  'Crystal Kelly',
#  'Crystal Langhorne',
#  'Crystal Robinson',
#  'Crystal Smith',
#  'Cynthia Cooper',
#  'Daedra Charles',
#  'Daliborka Vilipic',
#  'Dalma Ivanyi',
#  'Damiris Dantas',
#  'Dana Wynne',
#  'Danielle Adams',
#  'Danielle Crockrom',
#  'Danielle McCray',
#  'Danielle McCulley',
#  'Danielle Page',
#  'Danielle Robinson',
#  'Danielle Viglione',
#  'Darxia Morris',
#  'Davalyn Cunningham',
#  'Davellyn Whyte',
#  'Dawn Evans',
#  'Dawn Staley',
#  'DeLisha Milton-Jones',
#  'DeMya Walker',
#  'DeTrina White',
#  'DeWanna Bonner',
#  'Deanna Jackson',
#  'Deanna Nolan',
#  'Dearica Hamby',
#  'Debbie Black',
#  'Deborah Carter',
#  'Debra Williams',
#  'Dee Davis',
#  'Dena Head',
#  'Denique Graves',
#  'Desiree Francis',
#  'Devereaux Peters',
#  'Diamond DeShields',
#  'Diana Taurasi',
#  'Dominique Canty',
#  'Doneeka Lewis',
#  'Donna Harrington',
#  'Dymond Simon',
#  'E.C. Hill',
#  'Ebony Hoffman',
#  'Edna Campbell',
#  'Edniesha Curry',
#  'Edwige Lawson-Wade',
#  'Edwina Brown',
#  'Elaine Powell',
#  'Elena Baranova',
#  'Elena Delle Donne',
#  'Elena Shakirova',
#  'Elena Tornikidou',
#  'Elisa Aguilar',
#  'Elisabeth Cebrian',
#  'Elizabeth Williams',
#  'Emilie Gomis',
#  'Emma Cannon',
#  'Emma Meesseman',
#  'Emmeline Ndongue',
#  'Endy Miyem',
#  'Epiphanny Prince',
#  'Erica McCall',
#  'Erica Wheeler',
#  'Erica White',
#  'Erika de Souza',
#  'Erin Alexander',
#  'Erin Grant',
#  'Erin Perperoglou',
#  'Erin Phillips',
#  'Erin Thorn',
#  'Erlana Larkins',
#  'Essence Carson',
#  'Eugenia Rycraw',
#  'Eva Nemcova',
#  'Evanthia Maltsi',
#  'Evelyn Akhator',
#  'Evgeniya Belyakova',
#  'Ewelina Kobryn',
#  'Farhiya Abdi',
#  'Felicia Chester',
#  'Felicia Ragland',
#  'Feyonda Fitzgerald',
#  'Florina Pascalau',
#  'Fran Harris',
#  'Francesca Zara',
#  'Franthea Price',
#  'Frida Eldebrink',
#  'Gabby Williams',
#  'Gabriela Marginean',
#  'Gennifer Brandon',
#  'Georgia Schweitzer',
#  'Gergana Branzova',
#  'Gergana Slavtcheva',
#  'Gillian Goring',
#  'Giuliana Mendiola',
#  'Glory Johnson',
#  'Gordana Grubin',
#  'Grace Daley',
#  'Greta Koss',
#  'Gwen Jackson',
#  'Gwen Slaughter',
#  'Haixia Zheng',
#  'Hajdana Radunovic',
#  'Haley Peters',
#  'Hamchetou Maiga-Ba',
#  'Han Xu',
#  'Heather Burge',
#  'Heather Butler',
#  'Heather Owen',
#  'Heidi Burge',
#  'Helen Darling',
#  'Helen Luz',
#  'Hind Ben Abdelkader',
#  'Iciss Tillis',
#  'Ify Ibekwe',
#  'Ilona Korstine',
#  'Imani McGee-Stafford',
#  'Imani Wright',
#  'Inga Orekhova',
#  'Irina Osipova',
#  'Isabel Sanchez',
#  'Isabelle Fijalkowski',
#  'Isabelle Harrison',
#  'Itoro Umoh-Coleman',
#  'Ivory Latta',
#  'Iziane Castro Marques',
#  'Jacinta Monroe',
#  'Jacki Gemelos',
#  'Jackie Moore',
#  'Jackie Stiles',
#  'Jackie Young',
#  'Jaclyn Johnson',
#  'Jacqueline Batteast',
#  'Jae Kingi-Cross',
#  'Jaime Nared',
#  'Jameka Jones',
#  'Jamie Carey',
#  'Jamie Cassidy',
#  'Jamie Redd',
#  'Jamie Weisner',
#  'Jamierra Faulkner',
#  'Jamila Wideman',
#  'Jana Vesela',
#  'Janel McCarville',
#  'Janell Burse',
#  'Janeth Arcain',
#  'Janice Braxton',
#  'Jannon Roland',
#  'Jantel Lavender',
#  'Jasmina Perazic-Gipe',
#  'Jasmine Hassell',
#  'Jasmine James',
#  'Jasmine Lister',
#  'Jasmine Thomas',
#  'Jayne Appel-Marinelli',
#  'Jaynetta Saunders',
#  'Jazmon Gwathmey',
#  'Jeanette Pohlen-Mavunga',
#  'Jelena Dubljevic',
#  'Jelena Milovanovic',
#  'Jene Morris',
#  "Jenna O'Hea",
#  'Jenni Benningfield',
#  'Jennie Simms',
#  'Jennifer Azzi',
#  'Jennifer Derevjanik',
#  'Jennifer Gillom',
#  'Jennifer Hamson',
#  'Jennifer Howard',
#  'Jennifer Lacy',
#  "Jennifer O'Neill",
#  'Jennifer Rizzotti',
#  'Jennifer Smith',
#  'Jennifer Whittle',
#  'Jenny Boucek',
#  'Jenny Mowe',
#  'Jessica Adair',
#  'Jessica Bibby',
#  'Jessica Breland',
#  'Jessica Brungo',
#  'Jessica Davenport',
#  'Jessica Moore',
#  'Jessica Shepard',
#  'Jessie Hicks',
#  'Jewell Loyd',
#  'JiSu Park',
#  'Jia Perkins',
#  'Jill Chapman-Daily',
#  'Jillian Alleyne',
#  'Jocelyn Penn',
#  'Jolene Anderson',
#  'Jonquel Jones',
#  'Jordan Adams',
#  'Jordan Hooper',
#  'Jordin Canada',
#  'Joslyn Tinkle',
#  'Joy Cheek',
#  'Joy Holmes-Harris',
#  'Judy Mosley-McAfee',
#  'Julie Wojta',
#  'Jung Sun-Min',
#  'Jurgita Streimikyte',
#  'K.B. Sharp',
#  'Kaayla Chones',
#  'Kaela Davis',
#  'Kahleah Copper',
#  'Kalana Greene',
#  'Kalani Brown',
#  'Kaleena Mosqueda-Lewis',
#  'Kamela Gissendanner',
#  'Kamesha Hairston',
#  'Kamiko Williams',
#  'Kamila Vodichkova',
#  'Kara Braxton',
#  'Kara Lawson',
#  'Kara Wolters',
#  'Karen Booker',
#  'Karima Christmas-Kelly',
#  'Karlie Samuelson',
#  'Kasha Terry',
#  'Katarina Lazic',
#  'Katasha Artis',
#  'Kate Paye',
#  'Kate Starbird',
#  'Katelan Redmon',
#  'Kathrin Ress',
#  'Katie Cronin',
#  'Katie Douglas',
#  'Katie Gearlds',
#  'Katie Lou Samuelson',
#  'Katie Mattera',
#  'Katie Smith',
#  'Katrina Colleton',
#  'Katrina Hibbert',
#  'Katryna Gaither',
#  'Katy Steding',
#  'Kayla Alexander',
#  'Kayla McBride',
#  'Kayla Pedersen',
#  'Kayla Thornton',
#  'Kayte Christensen',
#  'Kedra Holland-Corn',
#  'Keisha Anderson',
#  'Keisha Hampton',
#  'Keitha Dickerson',
#  'Kelley Cain',
#  'Kelley Gibson',
#  'Kellie Jolly Harper',
#  'Kelly Boucher',
#  'Kelly Faris',
#  'Kelly Mazzante',
#  'Kelly Miller',
#  'Kelly Santos',
#  'Kelly Schumacher',
#  'Kelsey Bone',
#  'Kelsey Griffin',
#  'Kelsey Mitchell',
#  'Kelsey Plum',
#  'Kendra Wecker',
#  'Kenisha Bell',
#  'Kennedy Burke',
#  'Keri Chaconas',
#  'Kerri Gardin',
#  'Ketia Swanier',
#  'Khadijah Whittington',
#  'Kia Nurse',
#  'Kia Vaughn',
#  'Kiah Stokes',
#  'Kiesha Brown',
#  'Kim Gessig',
#  'Kim Mestdagh',
#  'Kim Perrot',
#  'Kim Smith',
#  'Kim Williams',
#  'Kimberly Beck',
#  'Kisha Ford',
#  'Korie Hlede',
#  'Kristen Mann',
#  "Kristen O'Neill",
#  'Kristen Rasmussen',
#  'Kristen Veal',
#  'Kristi Cirone',
#  'Kristi Harrower',
#  'Kristi Toliver',
#  'Kristin Folkl',
#  'Kristin Haynie',
#  'Kristine Anigwe',
#  'Krystal Thomas',
#  'Krystal Vaughn',
#  'Krystyna Lara',
#  'Kym Hampton',
#  'Kym Hope',
#  "La'Keshia Frett",
#  "La'Shawn Brown",
#  "La'Tangela Atkinson",
#  'LaCharlotte Smith',
#  'LaNeishea Caufield',
#  'LaQuanda Barksdale',
#  'LaTonya Johnson',
#  'LaToya Bond',
#  'LaToya Sanders',
#  'LaToya Thomas',
#  'Lady Grooms',
#  'Lanay Montgomery',
#  'Larecha Jones',
#  'Latasha Byears',
#  'Laura Harper',
#  'Laura Macchi',
#  'Laura Summerton',
#  'Laure Savasta',
#  'Lauren Ervin',
#  'Lauren Jackson',
#  'Laurie Koehn',
#  'Layshia Clarendon',
#  "Le'coe Willingham",
#  'Leah Rush',
#  'Leigh Aziz',
#  'Leila Sobral',
#  'Leilani Mitchell',
#  'Lenae Williams',
#  'Lesley Brown',
#  'Leslie Johnson',
#  'Leticia Romero',
#  'Levys Torres',
#  'Lexie Brown',
#  'Linda Burgess',
#  'Linda Frohlich',
#  'Lindsay Allen',
#  'Lindsay Bowen',
#  'Lindsay Taylor',
#  'Lindsay Whalen',
#  'Lindsay Wisdom-Hylton',
#  'Lindsey Harding',
#  'Lindsey Moore',
#  'Lindsey Yamasaki',
#  'Linnae Harper',
#  'Lisa Harrison',
#  'Lisa Leslie',
#  'Lisa Willis',
#  'Liz Cambage',
#  'Liz Moeggenberg',
#  'Loree Moore',
#  'Lucienne Berthieu',
#  'Lynetta Kizer',
#  'Lynette Woodard',
#  'Lynn Pride',
#  'Mactabene Amachree',
#  'Madinah Slaise',
#  'Maggie Lucas',
#  'Maimouna Diarra',
#  'Maite Cazorla',
#  'Makayla Epps',
#  'Mandisa Stevenson',
#  'Marcedes Walker',
#  'Marcie Alberts',
#  'Maren Walseth',
#  'Margo Dydek',
#  'Margo Graham',
#  'Margold Clark',
#  'Maria Stepanova',
#  'Maria Vadeeva',
#  'Marianna Tolo',
#  'Marie Ferdinand-Harris',
#  'Marie Gulich',
#  'Marina Ferragut',
#  'Marina Mabrey',
#  'Marine Johannes',
#  'Marion Jones',
#  'Marissa Coleman',
#  'Markeisha Gatling',
#  'Markita Aldridge',
#  'Marla Brumfield',
#  'Marlies Askamp',
#  'Marlous Nieuwveen',
#  'Marta Fernandez',
#  'Marta Xargay',
#  'Martina Weber',
#  'Matee Ajavon',
#  'Maya Moore',
#  'Maylana Martin',
#  'Megan Compain',
#  'Megan Duffy',
#  'Megan Frazee',
#  'Megan Gustafson',
#  'Megan Mahoney',
#  'Meighan Simmons',
#  'Mercedes Russell',
#  'Merlakia Jones',
#  'MerleLynn Lange-Harris',
#  'Mery Andrade',
#  'Mfon Udoka',
#  'Miao Lijie',
#  'Michaela Pavlickova',
#  'Michele Timms',
#  'Michele Van Gorp',
#  'Michelle Brogan',
#  'Michelle Campbell',
#  'Michelle Cleary',
#  'Michelle Edwards',
#  'Michelle Greco',
#  'Michelle Marciniak',
#  'Michelle Reed',
#  'Michelle Snow',
#  'Mikiko Hagiwara',
#  'Mila Nikolich',
#  'Milena Flores',
#  'Milica Vukadinovic',
#  'Miranda Ayim',
#  'Mistie Bass',
#  'Molly Tuter',
#  'Monica Lamb',
#  'Monica Maxwell',
#  'Monica Wright',
#  'Monique Ambers',
#  'Monique Billings',
#  'Monique Coker',
#  'Monique Currie',
#  'Morenike Atunrase',
#  'Morgan Tuck',
#  'Moriah Jefferson',
#  'Murriel Page',
#  'Mwadi Mabika',
#  'Myisha Hines-Allen',
#  'Nadia Colhado',
#  'Nadine Domond',
#  'Nadine Malcolm',
#  'Nadirah McKenith',
#  'Nakia Sanford',
#  'Nancy Lieberman',
#  'Naomi Mulitauaopele',
#  'Napheesa Collier',
#  'Natalia Vodopyanova',
#  'Natalie Achonwa',
#  'Natalie Novosel',
#  'Natalie Williams',
#  'Natasha Cloud',
#  'Natasha Howard',
#  'Natasha Lacy',
#  'Natisha Hiedeman',
#  'Navonda Moore',
#  'Nayo Raincock-Ekunwe',
#  'Nekeshia Henderson',
#  'Nevriye Yilmaz',
#  'Nia Coffey',
#  'Nicky Anosike',
#  'Nicky McCrimmon',
#  'Nicole Kubik',
#  'Nicole Levandusky',
#  'Nicole Levesque',
#  'Nicole Ohlde',
#  'Nicole Powell',
#  'Niele Ivey',
#  'Niesa Johnson',
#  'Nikki Blue',
#  'Nikki Greene',
#  'Nikki McCray',
#  'Nikki Teasley',
#  'Nina Bjedov',
#  'Nirra Fields',
#  'Nneka Ogwumike',
#  'Noelle Quinn',
#  'Nuria Martinez',
#  'Nykesha Sales',
#  'Nyree Roberts',
#  'Octavia Blue',
#  'Odyssey Sims',
#  'Oksana Zakaluzhnaya',
#  'Olayinka Sanni',
#  'Olga Firsova',
#  'Olympia Scott',
#  'Paige Sauer',
#  'Pamela McGee',
#  'Paris Kea',
#  'Pat Luckey',
#  'Pauline Jordan',
#  'Penny Moore',
#  'Penny Taylor',
#  'Penny Toler',
#  'Petra Ujhelyi',
#  'Pietra Gay',
#  'Plenette Pierson',
#  'Polina Tzekova',
#  'Pollyanna Johns Kimbrough',
#  'Porsha Phillips',
#  'Quacy Barnes',
#  'Quanitra Hollingsworth',
#  'Quianna Chaney',
#  'Rachael Sporn',
#  'Rachel Banham',
#  'Rachel Hollivay',
#  'Rachel Jarry',
#  'Raegan Scott',
#  'Raffaella Masciadri',
#  'Raigyne Louis',
#  'Ramu Tokashiki',
#  'Rankica Sarenac',
#  'Rashanda McCants',
#  'Razija Brcaninovic',
#  'Rebecca Allen',
#  'Rebecca Lobo',
#  'Rebekkah Brunson',
#  'Rehema Stephens',
#  'Renee Montgomery',
#  'Renee Robinson',
#  'Reshanda Gray',
#  'Reshea Bristol',
#  'Rhonda Banchero',
#  'Rhonda Blades',
#  'Rhonda Mapp',
#  'Riquna Williams',
#  'Rita Williams',
#  'Robin Threatt-Elliott',
#  'Romana Hamzova',
#  'Roneeka Hodges',
#  'Rushia Brown',
#  'Ruth Hamblin',
#  'Ruth Riley',
#  'Ruthie Bolton',
#  'Ryneldi Becenti',
#  'Sabrina Palie',
#  'Samantha Logic',
#  'Samantha Prahalis',
#  'Sami Whitcomb',
#  'Sancho Lyttle',
#  'Sandora Irvin',
#  'Sandra Van Embricqs',
#  'Sandrine Gruda',
#  'Sandy Brondello',
#  'Saniya Chong',
#  'Sasha Goodlett',
#  'Scholanda Dorrell',
#  'Seimone Augustus',
#  'Semeka Randall',
#  'Sequoia Holmes',
#  'Shae Kelley',
#  'Shalee Lehning',
#  'Shalonda Enis',
#  'Shameka Christon',
#  'Shanece McKinney',
#  'Shanele Stires',
#  'Shanna Zolman',
#  'Shannon Bobbitt',
#  'Shannon Johnson',
#  'Shantia Owens',
#  'Shao Ting',
#  'Shaquala Williams',
#  "Sharnee' Zoll",
#  'Sharon Manning',
#  'Shatori Walker-Kimbrough',
#  'Shaunzinski Gortman',
#  'Shavonte Zellous',
#  'Shay Doron',
#  'Shay Murphy',
#  'Shea Mahoney',
#  'Sheila Lambert',
#  'Shekinna Stricklen',
#  'Shenise Johnson',
#  'Shereka Wright',
#  'Sheri Sam',
#  'Sherill Baker',
#  'Sheryl Swoopes',
#  'Shey Peddy',
#  'Shona Thorburn',
#  'Shoni Schimmel',
#  'Shyra Ely-Gash',
#  'Sidney Spencer',
#  'Simone Edwards',
#  'Skylar Diggins-Smith',
#  'Slobodanka Tuvic',
#  'Sonia Chase',
#  'Sonja Henning',
#  'Sonja Mallory',
#  'Sonja Petrovic',
#  'Sonja Tate',
#  'Sophia Witherspoon',
#  'Sophia Young-Malcolm',
#  'Sophie Brunner',
#  'Sophie Cunningham',
#  'Stacey Dales',
#  'Stacey Ford',
#  'Stacey Lovelace',
#  'Stacey Thomas',
#  'Stacy Clinesmith',
#  'Stacy Frese',
#  'Stacy Stephens',
#  'Stefanie Dolson',
#  'Stephanie Mavunga',
#  'Stephanie Raymond',
#  'Stephanie Talbot',
#  'Stephanie White',
#  'Sue Bird',
#  'Sue Wicks',
#  'Sugar Rodgers',
#  'Sui Feifei',
#  'Summer Erb',
#  'Susan King Borchardt',
#  'Susanna Bonfiglio',
#  'Susie Hopson-Shelton',
#  'Suzie McConnell Serio',
#  'Suzy Batkovic-Brown',
#  'Svetlana Abrosimova',
#  'Swin Cash',
#  'Sydney Carter',
#  'Sydney Colson',
#  'Sydney Wiese',
#  'Sylvia Crawley',
#  'Sylvia Fowles',
#  "Ta'Shia Phillips",
#  'Tai Dillard',
#  'Taj McWilliams-Franklin',
#  'Tajama Abraham',
#  'Takeisha Lewis',
#  'Tamara James',
#  'Tamara Moore',
#  'Tamara Stocks',
#  'Tamecka Dixon',
#  'Tamera Young',
#  'Tamicha Jackson',
#  'Tamika Catchings',
#  'Tamika Whitmore',
#  'Tamika Williams',
#  'Tammi Reiss',
#  'Tammy Jackson',
#  'Tammy Sutton-Brown',
#  'Tan White',
#  'Tanae Davis-Cain',
#  'Tangela Smith',
#  'Tanisha Wright',
#  'Tanja Kostic',
#  'Tara Williams',
#  'Tari Phillips',
#  'Tasha Butts',
#  'Tasha Humphrey',
#  'Tausha Mills',
#  'Tawona Alhaleem',
#  'Tayler Hill',
#  'Taylor Lilley',
#  'Teaira McCowan',
#  'Teana Miller',
#  'Teana Muldrow',
#  'Temeka Johnson',
#  'Temi Fagbenle',
#  'Tera Bjorklund',
#  'Teresa Edwards',
#  'Teresa Weatherspoon',
#  'Tess Madgen',
#  'Texlin Quinney',
#  'Theresa Plaisance',
#  'Tia Jackson',
#  'Tia Paschal',
#  'Tianna Hawkins',
#  'Ticha Penicheiro',
#  'Tierra Ruffin-Pratt',
#  'Tiffani Johnson',
#  'Tiffany Bias',
#  'Tiffany Hayes',
#  'Tiffany Jackson-Jones',
#  'Tiffany McCain',
#  'Tiffany Mitchell',
#  'Tiffany Stansbury',
#  'Tiffany Travis',
#  'Tiffany Woosley',
#  'Tina Charles',
#  'Tina Nicholson',
#  'Tina Thompson',
#  'Toccara Williams',
#  'Toni Foster',
#  'Toni Young',
#  'Tonya Edwards',
#  'Tonya Massaline',
#  'Tora Suber',
#  'Tracy Henderson',
#  'Tracy Reid',
#  'Travesa Gant',
#  'Trena Trice',
#  'Tricia Bader Binford',
#  'Tricia Liston',
#  'Trina Frierson',
#  'Trisha Fallon',
#  'Trisha Stafford-Odom',
#  'Tully Bevilaqua',
#  "Tye'sha Fluker",
#  'Tynesha Lewis',
#  'Tyresa Smith',
#  'Ukari Figgs',
#  'Umeki Webb',
#  'Usha Gilmore',
#  'Val Berezhynska',
#  'Val Whiting-Raymond',
#  'Valeriane Ayayi',
#  'Valerie Still',
#  'Vanessa Hayden',
#  'Vanessa Nygaard',
#  'Vedrana Grgin-Fonseca',
#  'Venus Lacy',
#  'Vicki Baugh',
#  'Vicki Hall',
#  'Vickie Johnson',
#  'Vicky Bullett',
#  'Victoria Dunlap',
#  'Victoria Macaulay',
#  'Victoria Vivians',
#  'Waltiea Rolle',
#  'Wanda Guyton',
#  'Wanisha Smith',
#  'Wendi Willits',
#  'Wendy Palmer',
#  'Whitney Boddie',
#  'Whitney Knight',
#  'Willnett Crockett',
#  'Yelena Leuchanka',
#  'Yolanda Griffith',
#  'Yolanda Moore',
#  'Yolanda Paige',
#  'Yuko Oga',
#  'Yvette Angel',
#  'Yvonne Turner',
#  'Zane Tamane',
#  'Ziomara Morrison',
#  'Zoi Dimitrakou',
#  'Zuzana Zirkova',
#  'Zuzi Klimesova'}

# %% [markdown]
# ## Part 5 - Visualizations

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import numpy as np

y = []
x = []
for year in c:
    x.append(year)
    y.append(c[year])

y.reverse()
x.reverse()
    
figure(num=None, figsize=(20, 6), dpi=80, facecolor='w', edgecolor='k')
plt.bar(x, y, align='center', color='#aaddff')
plt.ylim(0, 300)
plt.ylabel('Number of Players')
plt.xlabel('Year')
plt.title('Number of Players Per Year')

plt.show()

# %% [markdown]
# This visualization that I came up with shows the number of players per year in the WNBA from 1997-2019. As you can see, the number of players floats around 150-250 players per year, with the highest being in 2002 with 219 active players in the WNBA.

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import numpy as np

age_sum = 0
count = 0
avg_ages = []

with open('../data/raw/wnba-player-stats.csv', 'r') as f:
    reader = csv.reader(f, delimiter=",", quotechar='"')
    next(reader, None)
    data_read = [row for row in reader]
    for year in x:
        age_sum = 0
        count = 0
        for i in range(len(data_read)):
            if data_read[i][2] == year:
                age_sum += int(data_read[i][3])
                count += 1
        avg_ages.append(age_sum/count)

figure(num=None, figsize=(20, 6), dpi=80, facecolor='w', edgecolor='k')
plt.bar(x, avg_ages, align='center', color='#aaddff')
plt.ylim(0, 30)
plt.ylabel('Average Age of Players')
plt.xlabel('Year')
plt.title('Average Age of Players Per Year')

plt.show()

# %% [markdown]
# This visualization shows the average age of players per year in the WNBA. As you can see, there is not much fluctuation with the average age of players as the average only ranges from 25-30 years old each WNBA season. We can see that the max average age of players was 27 in 2003.

# %% [markdown]
# ## Part 6 - Conclusion
#
# In conclusion, I was able to answer 3/3 of my questions. For the 1st question, the answer to that is to use the mean() function and put PERS as the parameter. So mean(PERS) returned 11.900386299253112
# which was the average Player Efficiency Rating in the WNBA from 1997-2019. For the 2nd question, I was able to do the same thing as above and use mean(ages) to find the answer which is 26.29513262941025. For the last question, I can use max(PERS) to find the answer to that which is 78.9. For the rest of my analysis, I was able to also find an extension to my second question which is to find the average age of players per year in the WNBA from 1997-2019. Above is the graph for that and it shows that the average age always hovers around 26. Overall, my analysis returned some pretty interesting statistics for WNBA players from 1997-2019.

# %%
mean(PERS)
# Out:
# 11.900386299253112

# %%
mean(ages)
# Out:
# 26.29513262941025

# %%
max(PERS)
# Out:
# 78.9
